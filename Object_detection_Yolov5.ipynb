# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# %cd /content/gdrive/MyDrive

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo

# %%
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies

# %%
import torch
import os
from IPython.display import Image, clear_output  # to display images

# %%
# %pwd

# %%
# !pip install --upgrade albumentations

# %%
# %%capture
# !pip install wandb --upgrade

# %%
import wandb
wandb.login()

# %%
# !pip list

# %%
# !pip uninstall opencv-python-headless==4.5.5.62

# %%
# !pip install opencv-python-headless==4.1.2.30

# %%
# !pip install -U PyYAML

# %%
# !python train.py --img 1280 --batch 16 --epochs 20000 --data /content/gdrive/MyDrive/AR/images/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --cache --project AR_sign_2 --name checkp \
   --bbox_interval 1

# %% [markdown]
# ## Evaluate on test image

# %%
# !pwd

# %%
# !python detect.py --weights ../gdrive/Mydrive/checkp4/weights/best.pt --img 640 --conf 0.1 --source ../AR/images/test

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

for imageName in glob.glob('../yolov5/runs/detect/exp3/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")
